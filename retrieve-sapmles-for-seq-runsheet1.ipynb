# %%
import pandas as pd
import numpy as np
import os, sys

# %%
cols = ['Sample Name', 'Reporter', 'CT', 'Ct Mean']

data = pd.DataFrame(columns=cols)
data_list = []
for file in os.listdir():
    if file.endswith('.xls'):
        data_list.append(file)
    pass
sheets = sorted(data_list)

# %%
len(np.unique(np.array(sheets)))
# Out:
# 96

# %%
counts = 0
count = 0
sheets2 = []
othererrors = []

for sheet in sheets:
    df = pd.read_excel(f'{sheet}', header=50)
    try:
        df2 = df[cols]
        data = data.append(df2, ignore_index=True)
        count += 1
    except KeyError:
        sheets2.append(sheet)
    except:
        print("Unexpected error:", sys.exc_info()[0])
        print(f'File: {sheet}')
        raise

# %%
counts += count
print(f'data rows: {data.shape[0]}')
print(f"this batch's count: {count}")
print(f'overall counts: {counts}')
# Out:
# data rows: 3435
# this batch's count: 54
# overall counts: 54

# %%
count = 0
sheets3 = []
for sheet in sheets2:
    df = pd.read_excel(f'{sheet}', header=48)
    try:
        df2 = df[cols]
        data = data.append(df2, ignore_index=True)
        count += 1
    except KeyError:
        sheets3.append(sheet)
    except: 
        print("Unexpected error:", sys.exc_info()[0])
        print(f'File: {sheet}')
        raise

# %%
counts += count
print(f'data rows: {data.shape[0]}')
print(f"this batch's count: {count}")
print(f'overall counts: {counts}')
# Out:
# data rows: 3567
# this batch's count: 4
# overall counts: 58

# %%
count = 0
sheets4 = []
for sheet in sheets3:
    df = pd.read_excel(f'{sheet}', header=46)
    try:
        df2 = df[cols]
        data = data.append(df2, ignore_index=True)
        count += 1
    except KeyError:
        sheets4.append(sheet)
    except: 
        print("Unexpected error:", sys.exc_info()[0])
        print(f'File: {sheet}')
        raise

# %%
counts += count
print(f'data rows: {data.shape[0]}')
print(f"this batch's count: {count}")
print(f'overall counts: {counts}')
# Out:
# data rows: 5358
# this batch's count: 23
# overall counts: 81

# %%
cols2 = ['Sample Name', 'Reporter', 'Cт', 'Cт Mean']
count = 0
sheets5 = []
for sheet in sheets4:
    df = pd.read_excel(f'{sheet}', header=7)
    try:
        df2 = df[cols2]
        df2.columns = cols
        data = data.append(df2, ignore_index=True)
        count += 1
    except KeyError:
        sheets5.append(sheet)
    except: 
        pprint("Unexpected error:", sys.exc_info()[0])
        print(f'File: {sheet}')
        raise

# %%
counts += count
print(f'data rows: {data.shape[0]}')
print(f"this batch's count: {count}")
print(f'overall counts: {counts}')
# Out:
# data rows: 9784
# this batch's count: 15
# overall counts: 96

# %%
data.head(15)
# Out:
#    Sample Name Reporter            CT    Ct Mean
# 0   COVC 23722      FAM  Undetermined        NaN
# 1   COVC 23722      VIC  Undetermined        NaN
# 2   COVC 23722      CY5     24.697775  24.697775
# 3   COVC 23723      FAM  Undetermined        NaN
# 4   COVC 23723      VIC  Undetermined        NaN
# 5   COVC 23723      CY5     25.171791  25.171791
# 6   COVC 23724      FAM  Undetermined        NaN
# 7   COVC 23724      VIC  Undetermined        NaN
# 8   COVC 23724      CY5     27.905439  27.905439
# 9   COVC 23725      FAM  Undetermined        NaN
# 10  COVC 23725      VIC  Undetermined        NaN
# 11  COVC 23725      CY5     26.896544  26.896544
# 12  COVC 23726      FAM  Undetermined        NaN
# 13  COVC 23726      VIC  Undetermined        NaN
# 14  COVC 23726      CY5     28.586617  28.586617

# %%
data[data['Sample Name'] == 'COVC22821']
# Out:
#      Sample Name Reporter         CT  Ct Mean
# 1572   COVC22821      FAM  34.898037      NaN
# 1573   COVC22821      VIC  37.244049      NaN
# 1574   COVC22821      CY5  25.827465      NaN

# %%
data2 = data[data['CT'] != 'Undetermined']

# %%
data3 = data2[data2['Reporter'].isin(['FAM', 'VIC', 'ABY']) == True]

# %% [raw]
# data2b = data2[data2['CT'] != 'JUN']

# %% [raw]
# data2c = data2b[data2b['CT'] != 'ABY']

# %% [raw]
# data3 = data2c[data2c['Reporter'] != 'CY5']

# %%
data4 = data3[data3.duplicated('Sample Name', False) == True]

# %%
data4.head(10)
# Out:
#    Sample Name Reporter         CT    Ct Mean
# 18          PC      FAM  29.807711  29.807711
# 19          PC      VIC  30.448586  30.448586
# 21  COVC 23742      FAM  23.518826  23.518826
# 22  COVC 23742      VIC  25.825026  25.825026
# 24  COVC 23743      FAM   25.65292  25.652920
# 25  COVC 23743      VIC  27.459602  27.459602
# 27  COVC 23744      FAM    20.6896  20.689600
# 28  COVC 23744      VIC  22.637888  22.637888
# 30  COVC 23745      FAM  35.821041  35.821041
# 31  COVC 23745      VIC  36.711197  36.711197

# %%
data4.columns = ['Sample_Name', 'Reporter', 'CT', 'Ct_Mean']

# %%
def cov_rename(x):    
    try:
        if 'COV' not in x and '-R' in x:
            x = x.replace('-R', '')
        int(x)
        x = str(x).replace(str(x), f'COVC{str(x)}')
    except (ValueError, AttributeError, TypeError): x = str(x).replace(' ', '')
    return x

# %%
Sample_Name = data4['Sample_Name'].apply(lambda x: cov_rename(x))

# %% [raw]
# Sample_Name = data4['Sample_Name'].apply(lambda x: str(x).replace(str(x), f'COVC{str(x)}')
#                                              if (isinstance(x, (int, float))) else x.replace(' ', ''))

# %%
data4['Reporter'].unique()
# Out:
# array(['FAM', 'VIC', 'ABY'], dtype=object)

# %%
data5 = data4.assign(Sample_Name=Sample_Name)

# %%
data5.head()
# Out:
#    Sample_Name Reporter         CT    Ct_Mean
# 18          PC      FAM  29.807711  29.807711
# 19          PC      VIC  30.448586  30.448586
# 21   COVC23742      FAM  23.518826  23.518826
# 22   COVC23742      VIC  25.825026  25.825026
# 24   COVC23743      FAM   25.65292  25.652920

# %% [raw]
# data5_fam = data5[data5['Reporter'] == 'FAM']['CT'].rename('CT_FAM')

# %% [raw]
# data5_fam

# %% [raw]
# data5_vic = data5[data5['Reporter'] == 'VIC']['CT'].rename('CT_VIC')

# %% [raw]
# data5_vic

# %%
data6 = data5.sort_values(['Sample_Name', 'Reporter']).groupby('Sample_Name').mean()

# %%
data6#.head()
# Out:
#                Ct_Mean
# Sample_Name
# COVA-EQA     37.836151
# COVB-EQA     32.601500
# COVC1056     26.243371
# COVC1065     20.973464
# COVC1067     20.915163
# ...                ...
# Std2         26.866929
# Std3         30.575635
# Std4         34.131648
# Std5         36.907702
# nan          29.920797
#
# [326 rows x 1 columns]

# %%
#data6.reset_index().to_excel('cov-positiveCts.xlsx', index=False)

# %% [raw]
# data7 = data5.set_index('Sample_Name').assign(Ct_Mean = data6 ).reset_index()

# %% [raw]
# data7

# %% [raw]
# data8 = data7.sort_values('Sample_Name').drop_duplicates('Sample_Name')

# %% [raw]
# data8[data8['Sample_Name'] == 'COVC22821']

# %%
#data8.to_excel('cov-positivesCts.xlsx', index=False)

# %%
#biorepo = pd.read_excel('/home/douso/Documents/RunSheets/BioRepository/COVID -19 SAMPLE ARCHIVE.xlsx')

# %%
biorepo.head()
# Out:
#   Animal ID         Sample Type Date of sample collection Date Frozen  \
# 0     Human  Respiratory in VTM                       NaT         NaT
# 1     Human  Respiratory in VTM                       NaT         NaT
# 2     Human  Respiratory in VTM                       NaT         NaT
# 3     Human  Respiratory in VTM                       NaT         NaT
# 4     Human  Respiratory in VTM                       NaT         NaT
#
#   Volume aliquoted   Freezer No. ALIQUOT A Sample ID ALIQUOT A Storage box  \
# 0     Approx 1.2ml  BSL3 Freezer           COVA00001              SARS0001
# 1     Approx 1.2ml  BSL3 Freezer           COVA00002              SARS0001
# 2     Approx 1.2ml  BSL3 Freezer           COVA00003              SARS0001
# 3     Approx 1.2ml  BSL3 Freezer           COVA00004              SARS0001
# 4     Approx 1.2ml  BSL3 Freezer           COVA00005              SARS0001
#
#   Position in box ALIQUOT B Sample ID ALIQUOT B Storage box Position in box.1  \
# 0              1A            COVB0001              SARS0002                1A
# 1              2A            COVB0002              SARS0002                2A
# 2              3A            COVB0003              SARS0002                3A
# 3              4A            COVB0004              SARS0002                4A
# 4              5A            COVB0005              SARS0002                5A
#
#   Aliquoted by              Owner            Experiment          Project  \
# 0          NaN  Samuel/Edward/MOH  SARS-CoV-2 rt RT-PCR  COVID Diagnosis
# 1          NaN  Samuel/Edward/MOH  SARS-CoV-2 rt RT-PCR  COVID Diagnosis
# 2          NaN  Samuel/Edward/MOH  SARS-CoV-2 rt RT-PCR  COVID Diagnosis
# 3          NaN  Samuel/Edward/MOH  SARS-CoV-2 rt RT-PCR  COVID Diagnosis
# 4          NaN  Samuel/Edward/MOH  SARS-CoV-2 rt RT-PCR  COVID Diagnosis
#
#   Compiled by       Project code Unnamed: 18
# 0     stephen  BMZ002501 - COVID         NaN
# 1     stephen  BMZ002501 - COVID         NaN
# 2     stephen  BMZ002501 - COVID         NaN
# 3     stephen  BMZ002501 - COVID         NaN
# 4     stephen  BMZ002501 - COVID         NaN

# %%
cols = ['ALIQUOT A Sample ID', 'ALIQUOT A Storage box', 'Position in box',
       'ALIQUOT B Sample ID', 'ALIQUOT B Storage box', 'Position in box.1']

# %%
biorepo_loc = biorepo[cols]

# %%
#biorepo_loc.to_excel('/home/douso/Documents/RunSheets/BioRepository/COVID-19-Sample-Archive-loc.xlsx')

# %%
biorepo_loc.head()
# Out:
#     Freezer No. ALIQUOT A Sample ID ALIQUOT A Storage box Position in box  \
# 0  BSL3 Freezer           COVA00001              SARS0001              1A
# 1  BSL3 Freezer           COVA00002              SARS0001              2A
# 2  BSL3 Freezer           COVA00003              SARS0001              3A
# 3  BSL3 Freezer           COVA00004              SARS0001              4A
# 4  BSL3 Freezer           COVA00005              SARS0001              5A
#
#   ALIQUOT B Sample ID ALIQUOT B Storage box Position in box.1
# 0            COVB0001              SARS0002                1A
# 1            COVB0002              SARS0002                2A
# 2            COVB0003              SARS0002                3A
# 3            COVB0004              SARS0002                4A
# 4            COVB0005              SARS0002                5A

# %%
cts = pd.read_excel('/home/douso/Documents/RunSheets/Cts/cov-positiveCts.xlsx', '30AndBelowCts')

# %%
cts.head()
# Out:
#   Sample_Name  Ct_Mean
# 0   COVC21089     11.7
# 1   COVC22538     13.4
# 2   COVC22545     13.8
# 3   COVC23356     14.6
# 4   COVC23429     14.9

# %%
def cov_names(x):
    x = x.upper()
    if len(x) == 9:
        x = x.replace('COVC', 'COVA')
    elif len(x) == 8:
        x = x.replace('COVC', 'COVA0')
    elif len(x) == 7:
        x = x.replace('COVC', 'COVA00')
    elif len(x) == 6:
        x = x.replace('COVC', 'COVA000')
    elif len(x) == 5:
        x = x.replace('COVC', 'COVA0000')
    return x

# %%
def cov_namesA(x):
    x = str(x)
    if len(x) == 8:
        x = x.replace('COVA', 'COVA0')
    elif len(x) == 7:
        x = x.replace('COVA', 'COVA00')
    elif len(x) == 6:
        x = x.replace('COVA', 'COVA000')
    elif len(x) == 5:
        x = x.replace('COVA', 'COVA0000')
    elif len(x) == 4:
        x = x.replace('COVA', 'COVA00000')
    elif len(x) == 3:
        x = x.replace('COVA', 'COVA000000')
    elif len(x) == 2:
        x = x.replace('COVA', 'COVA0000000')
    return x

# %%
cts_cln = cts.assign(Sample_NameB=cts['Sample_Name'].apply(lambda x: cov_names(x)))

# %%
cts_cln
# Out:
#     Sample_Name  Ct_Mean Sample_NameB
# 0     COVC21089     11.7    COVA21089
# 1     COVC22538     13.4    COVA22538
# 2     COVC22545     13.8    COVA22545
# 3     COVC23356     14.6    COVA23356
# 4     COVC23429     14.9    COVA23429
# ..          ...      ...          ...
# 115   COVC23349     30.6    COVA23349
# 116   COVC23255     30.8    COVA23255
# 117   COVC23347     30.8    COVA23347
# 118   COVC23669     30.8    COVA23669
# 119   COVC23287     30.9    COVA23287
#
# [120 rows x 3 columns]

# %%
biorepo_loc_cln = biorepo_loc.assign(ALIQUOT_A_Sample_ID=biorepo_loc['ALIQUOT A Sample ID'].apply(lambda x: cov_namesA(x)))

# %%
biorepo_loc_cln.head()
# Out:
#     Freezer No. ALIQUOT A Sample ID ALIQUOT A Storage box Position in box  \
# 0  BSL3 Freezer           COVA00001              SARS0001              1A
# 1  BSL3 Freezer           COVA00002              SARS0001              2A
# 2  BSL3 Freezer           COVA00003              SARS0001              3A
# 3  BSL3 Freezer           COVA00004              SARS0001              4A
# 4  BSL3 Freezer           COVA00005              SARS0001              5A
#
#   ALIQUOT B Sample ID ALIQUOT B Storage box Position in box.1  \
# 0            COVB0001              SARS0002                1A
# 1            COVB0002              SARS0002                2A
# 2            COVB0003              SARS0002                3A
# 3            COVB0004              SARS0002                4A
# 4            COVB0005              SARS0002                5A
#
#   ALIQUOT_A_Sample_ID
# 0           COVA00001
# 1           COVA00002
# 2           COVA00003
# 3           COVA00004
# 4           COVA00005

# %%
cts_cln.head()
# Out:
#   Sample_Name  Ct_Mean Sample_NameB
# 0   COVC22538     13.4    COVA22538
# 1   COVC22545     13.8    COVA22545
# 2   COVC23356     14.6    COVA23356
# 3   COVC23429     14.9    COVA23429
# 4   COVC22543     15.1    COVA22543

# %%
cts_biorepo = cts_cln.set_index('Sample_NameB').merge(biorepo_loc_cln.set_index('ALIQUOT_A_Sample_ID'), how='inner', left_index=True, right_index=True)

# %%
cts_biorepo.head()
# Out:
#           Sample_Name  Ct_Mean   Freezer No. ALIQUOT A Sample ID  \
# COVA00854     COVC854     20.3  BSL3 Freezer             COVA854
# COVA00867     COVC867     23.6  BSL3 Freezer             COVA867
# COVA00893     COVC893     28.6  BSL3 Freezer             COVA893
# COVA00915     COVC915     26.1  BSL3 Freezer             COVA915
# COVA00962     COVC962     24.1  BSL3 Freezer             COVA962
#
#           ALIQUOT A Storage box Position in box ALIQUOT B Sample ID  \
# COVA00854              SARS0017             53F             COVB854
# COVA00867              SARS0017             66G             COVB867
# COVA00893              SARS0017             92J             COVB893
# COVA00915              SARS0019             14B             COVB915
# COVA00962              SARS0019             61G             COVB962
#
#           ALIQUOT B Storage box Position in box.1
# COVA00854              SARS0018               53F
# COVA00867              SARS0018               66G
# COVA00893              SARS0018               92J
# COVA00915              SARS0020               14B
# COVA00962              SARS0020               61G

# %%
seq_all = pd.read_excel('all-sequenced-covs.xlsx')

# %%
seq_all.head()
# Out:
#        covcs
# 0  COVC13064
# 1  COVC13125
# 2  COVC14272
# 3  COVC14288
# 4  COVC14304

# %%
sequenced = list(seq_all['covcs'].apply(lambda x: cov_names(x)))

# %%
cts_biorepo_srt = (cts_biorepo.reset_index().sort_values('index'))

# %%
cts_biorepo_srt
# Out:
#          index Sample_Name  Ct_Mean   Freezer No. ALIQUOT A Sample ID  \
# 0    COVA00854     COVC854     20.3  BSL3 Freezer             COVA854
# 1    COVA00867     COVC867     23.6  BSL3 Freezer             COVA867
# 2    COVA00893     COVC893     28.6  BSL3 Freezer             COVA893
# 3    COVA00915     COVC915     26.1  BSL3 Freezer             COVA915
# 4    COVA00962     COVC962     24.1  BSL3 Freezer             COVA962
# ..         ...         ...      ...           ...                 ...
# 114  COVA23743   COVC23743     26.6  BSL3 Freezer           COVA23743
# 115  COVA23744   COVC23744     21.7  BSL3 Freezer           COVA23744
# 116  COVA23752   COVC23752     24.4  BSL3 Freezer           COVA23752
# 117  COVA23754   COVC23754     27.5  BSL3 Freezer           COVA23754
# 118  COVA23763   COVC23763     17.6  BSL3 Freezer           COVA23763
#
#     ALIQUOT A Storage box Position in box ALIQUOT B Sample ID  \
# 0                SARS0017             53F             COVB854
# 1                SARS0017             66G             COVB867
# 2                SARS0017             92J             COVB893
# 3                SARS0019             14B             COVB915
# 4                SARS0019             61G             COVB962
# ..                    ...             ...                 ...
# 114              SARS0523             30C           COVB23743
# 115              SARS0523             31D           COVB23744
# 116              SARS0523             39D           COVB23752
# 117              SARS0523             41E           COVB23754
# 118              SARS0523             50E           COVB23763
#
#     ALIQUOT B Storage box Position in box.1
# 0                SARS0018               53F
# 1                SARS0018               66G
# 2                SARS0018               92J
# 3                SARS0020               14B
# 4                SARS0020               61G
# ..                    ...               ...
# 114              SARS0524               30C
# 115              SARS0524               31D
# 116              SARS0524               39D
# 117              SARS0524               41E
# 118              SARS0524               50E
#
# [119 rows x 10 columns]

# %%
final = cts_biorepo_srt[cts_biorepo_srt['index'].isin(sequenced) == False].sort_values(['index', 'Ct_Mean']).drop_duplicates('index', keep='last')

# %%
final#.head()
# Out:
#          index Sample_Name  Ct_Mean   Freezer No. ALIQUOT A Sample ID  \
# 0    COVA00854     COVC854     20.3  BSL3 Freezer             COVA854
# 1    COVA00867     COVC867     23.6  BSL3 Freezer             COVA867
# 2    COVA00893     COVC893     28.6  BSL3 Freezer             COVA893
# 3    COVA00915     COVC915     26.1  BSL3 Freezer             COVA915
# 4    COVA00962     COVC962     24.1  BSL3 Freezer             COVA962
# ..         ...         ...      ...           ...                 ...
# 110  COVA23706   COVC23706     28.4  BSL3 Freezer           COVA23706
# 111  COVA23712   COVC23712     19.8  BSL3 Freezer           COVA23712
# 112  COVA23715   COVC23715     19.1  BSL3 Freezer           COVA23715
# 113  COVA23742   COVC23742     24.7  BSL3 Freezer           COVA23742
# 118  COVA23763   COVC23763     17.6  BSL3 Freezer           COVA23763
#
#     ALIQUOT A Storage box Position in box ALIQUOT B Sample ID  \
# 0                SARS0017             53F             COVB854
# 1                SARS0017             66G             COVB867
# 2                SARS0017             92J             COVB893
# 3                SARS0019             14B             COVB915
# 4                SARS0019             61G             COVB962
# ..                    ...             ...                 ...
# 110              SARS0521             93J           COVB23706
# 111              SARS0521             99J           COVB23712
# 112              SARS0523              2A           COVB23715
# 113              SARS0523             29C           COVB23742
# 118              SARS0523             50E           COVB23763
#
#     ALIQUOT B Storage box Position in box.1
# 0                SARS0018               53F
# 1                SARS0018               66G
# 2                SARS0018               92J
# 3                SARS0020               14B
# 4                SARS0020               61G
# ..                    ...               ...
# 110              SARS0522               93J
# 111              SARS0522               99J
# 112              SARS0524                2A
# 113              SARS0524               29C
# 118              SARS0524               50E
#
# [78 rows x 10 columns]

# %%
#final.to_excel('/home/douso/Documents/RunSheets/BioRepository/cov-positiveCtsLocs.xlsx', index=False)
