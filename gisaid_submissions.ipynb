# %% [markdown]
# ## GISAID Metadata preparation

# %%
import pandas as pd
from datetime import  datetime

# %%
dt = datetime.today().strftime(format='%d-%m-%Y')

# %% [markdown]
# ### Load submission form

# %%
parent_dir = '/home/douso/SarsGenomics/Gisaid'
df_gisaid = pd.read_excel(f'{parent_dir}/20210222_EpiCoV.xls', 'Submissions')

# %%
df_gisaid.head()
# Out:
#          submitter                   fn                  covv_virus_name  \
# 0        Submitter       FASTA filename                       Virus name
# 1  GISAID username  all_sequences.fasta  hCoV-19/Country/Identifier/2020
#
#          covv_type             covv_passage covv_collection_date  \
# 0             Type  Passage details/history      Collection date
# 1  betacoronavirus      e.g. Original, Vero           2020-03-02
#
#                        covv_location  \
# 0                           Location
# 1  e.g. Continent / Country / Region
#
#                                   covv_add_location  \
# 0                   Additional location information
# 1  e.g. Cruise Ship, Convention, Live animal market
#
#                                            covv_host  \
# 0                                               Host
# 1  e.g. Human, Animal, Environment, Laboratory de...
#
#                               covv_add_host_info  ...  \
# 0                    Additional host information  ...
# 1  e.g. Patient infected while traveling in ….    ...
#
#                          covv_coverage  \
# 0                             Coverage
# 1  e.g. 70x, 1,000x, 10,000x (average)
#
#                                        covv_orig_lab covv_orig_lab_addr  \
# 0                                    Originating lab            Address
# 1  Where the clinical specimen or virus isolate w...                NaN
#
#                      covv_provider_sample_id  \
# 0  Sample ID given by originating laboratory
# 1                                        NaN
#
#                                        covv_subm_lab covv_subm_lab_addr  \
# 0                                     Submitting lab            Address
# 1  Where sequence data have been generated and su...                NaN
#
#                             covv_subm_sample_id             covv_authors  \
# 0  Sample ID given by the submitting laboratory                  Authors
# 1                                           NaN  e.g. Jane Doe, John Doe
#
#   covv_comment  comment_type
# 0      Comment  Comment Icon
# 1          NaN           NaN
#
# [2 rows x 30 columns]

# %%
df_gisaid.columns
# Out:
# Index(['submitter', 'fn', 'covv_virus_name', 'covv_type', 'covv_passage',
#        'covv_collection_date', 'covv_location', 'covv_add_location',
#        'covv_host', 'covv_add_host_info', 'covv_sampling_strategy',
#        'covv_gender', 'covv_patient_age', 'covv_patient_status',
#        'covv_specimen', 'covv_outbreak', 'covv_last_vaccinated',
#        'covv_treatment', 'covv_seq_technology', 'covv_assembly_method',
#        'covv_coverage', 'covv_orig_lab', 'covv_orig_lab_addr',
#        'covv_provider_sample_id', 'covv_subm_lab', 'covv_subm_lab_addr',
#        'covv_subm_sample_id', 'covv_authors', 'covv_comment', 'comment_type'],
#       dtype='object')

# %%
gisaid_header = ['submitter', 'fn', 'covv_virus_name', 'covv_type', 'covv_passage', 'DT_SAM_COLL', 
 'DT_SAM_RECEP', 'covv_location', 'covv_add_location','covv_host', 'covv_add_host_info', 'covv_sampling_strategy',
 'GEND', 'AGE_YRS', 'covv_patient_status', 'covv_specimen', 'covv_outbreak', 
 'covv_last_vaccinated', 'covv_treatment', 'covv_seq_technology', 'covv_assembly_method', 'covv_coverage', 
 'covv_orig_lab', 'covv_orig_lab_addr', 'S_NUM', 'covv_subm_lab', 'covv_subm_lab_addr', 
 'covv_subm_sample_id', 'covv_authors', 'covv_comment', 'comment_type']

# %%
len(gisaid_header)
# Out:
# 31

# %%
df_metadata = pd.read_excel('/home/douso/Documents/TrendData/Results/ResultsMerged/COVID19-results-merged-cln-pos.xlsx')

# %%
df_headers = df_metadata[['S_NUM', 'AGE_YRS', 'GEND', 'NAT', 
           'COUNT_RES',  
           'DT_SAM_COLL', 
           'DT_SAM_RECEP']]

# %%
df_seqd = pd.read_excel('/home/douso/Documents/TrendData/Results/ResultsMerged/all-sequenced-samples-IDs_30-08-2021.xlsx')[['SAMPLE']]

# %%
df_seqd_int = df_seqd[df_seqd['SAMPLE'].str.contains('KEM') == False]#.head()

# %%
seqd_list = list(df_seqd_int['SAMPLE'])

# %%
df_headers_int = df_headers[df_headers['S_NUM'].isin(seqd_list)]

# %%
df_headers_int_loc = df_headers_int.assign(covv_location = df_headers_int['COUNT_RES'].apply(lambda x: f'Africa/Kenya/{x}'))

# %%
df_headers_int_loc.head()
# Out:
#         S_NUM  AGE_YRS GEND    NAT COUNT_RES DT_SAM_COLL DT_SAM_RECEP  \
# 9   COVC00854     23.0    F  Kenya   Nairobi  2020-06-11          NaT
# 11  COVC00867     32.0    F  Kenya   Nairobi  2020-06-10          NaT
# 12  COVC00893     31.0    M  Kenya   Nairobi  2020-06-10          NaT
# 13  COVC00915     22.0    M  Kenya   Nairobi  2020-06-10          NaT
# 14  COVC00962     31.0    M  Kenya   Nairobi  2020-06-08   2020-06-14
#
#            covv_location
# 9   Africa/Kenya/Nairobi
# 11  Africa/Kenya/Nairobi
# 12  Africa/Kenya/Nairobi
# 13  Africa/Kenya/Nairobi
# 14  Africa/Kenya/Nairobi

# %%
df_subf = df_headers_int_loc

# %%
df_subf.head()
# Out:
#         S_NUM  AGE_YRS GEND    NAT COUNT_RES DT_SAM_COLL DT_SAM_RECEP  \
# 9   COVC00854     23.0    F  Kenya   Nairobi  2020-06-11          NaT
# 11  COVC00867     32.0    F  Kenya   Nairobi  2020-06-10          NaT
# 12  COVC00893     31.0    M  Kenya   Nairobi  2020-06-10          NaT
# 13  COVC00915     22.0    M  Kenya   Nairobi  2020-06-10          NaT
# 14  COVC00962     31.0    M  Kenya   Nairobi  2020-06-08   2020-06-14
#
#            covv_location
# 9   Africa/Kenya/Nairobi
# 11  Africa/Kenya/Nairobi
# 12  Africa/Kenya/Nairobi
# 13  Africa/Kenya/Nairobi
# 14  Africa/Kenya/Nairobi

# %%
submitter = ''
fn = ''
cvn = 'hCoV-19'
vt = 'betacoronavirus'
cp = 'Original'
cal = 'Unkown'
ch = 'Human'
cahi = 'Unkown'
css = 'Surveillance'
cps = ''
cps = 'Unkown'
cs = 'NP Swab'
co = 'Unkown'
clv = 'Unkown'
ct = 'Unkown'
cst = 'Illumina'
cam = pd.NA
cc = ''
col = 'International Livestock Research Institute'
cola = 'Uthiru, Naivasha road, Nairobi-Kenya'
# cpsi = 'ILRI'
csl = 'International Livestock Research Institute'
csla = 'Uthiru, Naivasha road, Nairobi-Kenya'
cssi = list(df_headers_int['S_NUM'])
ca = ''
ccomm = ''
ct = ''

# %%
df_subf['submitter'] = submitter
df_subf['fn'] = fn
df_subf['covv_virus_name'] = cvn
df_subf['covv_type'] = vt
df_subf['covv_passage'] = cp
df_subf['covv_add_location'] = cal
df_subf['covv_host'] = ch
df_subf['covv_add_host_info'] = cahi
df_subf['covv_sampling_strategy'] = css
df_subf['covv_patient_status'] = cps
df_subf['covv_specimen'] = cs
df_subf['covv_outbreak'] = co
df_subf['covv_last_vaccinated'] = clv
df_subf['covv_treatment'] = ct
df_subf['covv_seq_technology'] = cst
df_subf['covv_assembly_method'] = cam
df_subf['covv_coverage'] = cc
df_subf['covv_orig_lab'] = col
df_subf['covv_orig_lab_addr'] = cola
# df_subf['covv_provider_sample_id'] = cpsi
df_subf['covv_subm_lab'] = csl
df_subf['covv_subm_lab_addr'] = csla
df_subf['covv_subm_sample_id'] = cssi
df_subf['covv_authors'] = ca
df_subf['covv_comment'] = ccomm
df_subf['comment_type'] = ct
df_subf.shape
# Out:
# (858, 33)

# %%
df_subf.columns
# Out:
# Index(['S_NUM', 'AGE_YRS', 'GEND', 'NAT', 'COUNT_RES', 'DT_SAM_COLL',
#        'DT_SAM_RECEP', 'covv_location', 'submitter', 'fn', 'covv_virus_name',
#        'covv_type', 'covv_passage', 'covv_add_location', 'covv_host',
#        'covv_add_host_info', 'covv_sampling_strategy', 'covv_patient_status',
#        'covv_specimen', 'covv_outbreak', 'covv_last_vaccinated',
#        'covv_treatment', 'covv_seq_technology', 'covv_assembly_method',
#        'covv_coverage', 'covv_orig_lab', 'covv_orig_lab_addr', 'covv_subm_lab',
#        'covv_subm_lab_addr', 'covv_subm_sample_id', 'covv_authors',
#        'covv_comment', 'comment_type'],
#       dtype='object')

# %%
# df_subf.assign(submitter = submitter)
# df_subf.assign(fn = fn)
# df_subf.assign(covv_virus_name = cvn)
# df_subf.assign(covv_type = cp)
# df_subf.assign(covv_host = ch)
# df_subf.assign(covv_add_host_info = cahi)
# df_subf.assign(covv_sampling_strategy = css)
# df_subf.assign(covv_patient_status = cps)
# df_subf.assign(covv_specimen = cs)
# df_subf.assign(covv_outbreak = co)
# df_subf.assign(covv_last_vaccinated = clv)
# df_subf.assign(covv_treatment = ct)
# df_subf.assign(covv_seq_technology = cst)
# df_subf.assign(covv_assembly_method = cam)
# df_subf.assign(covv_coverage = cc)
# df_subf.assign(covv_orig_lab = col)
# df_subf.assign(covv_orig_lab_addr = cola)
# df_subf.assign(covv_subm_lab = csl)
# df_subf.assign(covv_subm_lab_addr = csla)
# df_subf.assign(covv_subm_sample_id = cssi)
# df_subf.assign(covv_authors = ca)
# df_subf.assign(covv_comment = ccomm)
# df_subf.assign(comment_type = ct)
# df_subf.shape

# %%
df_subf1 = df_subf.drop(['NAT', 'COUNT_RES'], axis=1)

# %%
df_subf1.head()
# Out:
#         S_NUM  AGE_YRS GEND DT_SAM_COLL DT_SAM_RECEP         covv_location  \
# 9   COVC00854     23.0    F  2020-06-11          NaT  Africa/Kenya/Nairobi
# 11  COVC00867     32.0    F  2020-06-10          NaT  Africa/Kenya/Nairobi
# 12  COVC00893     31.0    M  2020-06-10          NaT  Africa/Kenya/Nairobi
# 13  COVC00915     22.0    M  2020-06-10          NaT  Africa/Kenya/Nairobi
# 14  COVC00962     31.0    M  2020-06-08   2020-06-14  Africa/Kenya/Nairobi
#
#    submitter fn covv_virus_name        covv_type  ... covv_assembly_method  \
# 9                       hCoV-19  betacoronavirus  ...                 <NA>
# 11                      hCoV-19  betacoronavirus  ...                 <NA>
# 12                      hCoV-19  betacoronavirus  ...                 <NA>
# 13                      hCoV-19  betacoronavirus  ...                 <NA>
# 14                      hCoV-19  betacoronavirus  ...                 <NA>
#
#    covv_coverage                               covv_orig_lab  \
# 9                 International Livestock Research Institute
# 11                International Livestock Research Institute
# 12                International Livestock Research Institute
# 13                International Livestock Research Institute
# 14                International Livestock Research Institute
#
#                       covv_orig_lab_addr  \
# 9   Uthiru, Naivasha road, Nairobi-Kenya
# 11  Uthiru, Naivasha road, Nairobi-Kenya
# 12  Uthiru, Naivasha road, Nairobi-Kenya
# 13  Uthiru, Naivasha road, Nairobi-Kenya
# 14  Uthiru, Naivasha road, Nairobi-Kenya
#
#                                  covv_subm_lab  \
# 9   International Livestock Research Institute
# 11  International Livestock Research Institute
# 12  International Livestock Research Institute
# 13  International Livestock Research Institute
# 14  International Livestock Research Institute
#
#                       covv_subm_lab_addr covv_subm_sample_id covv_authors  \
# 9   Uthiru, Naivasha road, Nairobi-Kenya           COVC00854
# 11  Uthiru, Naivasha road, Nairobi-Kenya           COVC00867
# 12  Uthiru, Naivasha road, Nairobi-Kenya           COVC00893
# 13  Uthiru, Naivasha road, Nairobi-Kenya           COVC00915
# 14  Uthiru, Naivasha road, Nairobi-Kenya           COVC00962
#
#    covv_comment comment_type
# 9
# 11
# 12
# 13
# 14
#
# [5 rows x 31 columns]

# %%
df_subf1[df_subf1['DT_SAM_COLL'].isna() == True]
# Out:
#            S_NUM  AGE_YRS GEND DT_SAM_COLL DT_SAM_RECEP         covv_location  \
# 18     COVC01056      NaN    M         NaT   2020-06-15      Africa/Kenya/nan
# 19     COVC01065     25.0    M         NaT   2020-06-15  Africa/Kenya/Nairobi
# 20     COVC01067     43.0    M         NaT   2020-06-15  Africa/Kenya/Nairobi
# 21     COVC01069     26.0    M         NaT   2020-06-15  Africa/Kenya/Kajiado
# 1069   COVC12481     39.0    M         NaT   2020-10-06   Africa/Kenya/Kiambu
# ...          ...      ...  ...         ...          ...                   ...
# 3809  NPHL-12780      NaN  NaN         NaT   2021-04-07      Africa/Kenya/nan
# 3810       NPHL1      NaN  NaN         NaT   2021-04-07      Africa/Kenya/nan
# 3811       NPHL2      NaN  NaN         NaT   2021-04-07      Africa/Kenya/nan
# 3812       NPHL3      NaN  NaN         NaT   2021-04-07      Africa/Kenya/nan
# 3813       NPHL4      NaN  NaN         NaT   2021-04-07      Africa/Kenya/nan
#
#      submitter fn covv_virus_name        covv_type  ... covv_assembly_method  \
# 18                        hCoV-19  betacoronavirus  ...                 <NA>
# 19                        hCoV-19  betacoronavirus  ...                 <NA>
# 20                        hCoV-19  betacoronavirus  ...                 <NA>
# 21                        hCoV-19  betacoronavirus  ...                 <NA>
# 1069                      hCoV-19  betacoronavirus  ...                 <NA>
# ...        ... ..             ...              ...  ...                  ...
# 3809                      hCoV-19  betacoronavirus  ...                 <NA>
# 3810                      hCoV-19  betacoronavirus  ...                 <NA>
# 3811                      hCoV-19  betacoronavirus  ...                 <NA>
# 3812                      hCoV-19  betacoronavirus  ...                 <NA>
# 3813                      hCoV-19  betacoronavirus  ...                 <NA>
#
#      covv_coverage                               covv_orig_lab  \
# 18                  International Livestock Research Institute
# 19                  International Livestock Research Institute
# 20                  International Livestock Research Institute
# 21                  International Livestock Research Institute
# 1069                International Livestock Research Institute
# ...            ...                                         ...
# 3809                International Livestock Research Institute
# 3810                International Livestock Research Institute
# 3811                International Livestock Research Institute
# 3812                International Livestock Research Institute
# 3813                International Livestock Research Institute
#
#                         covv_orig_lab_addr  \
# 18    Uthiru, Naivasha road, Nairobi-Kenya
# 19    Uthiru, Naivasha road, Nairobi-Kenya
# 20    Uthiru, Naivasha road, Nairobi-Kenya
# 21    Uthiru, Naivasha road, Nairobi-Kenya
# 1069  Uthiru, Naivasha road, Nairobi-Kenya
# ...                                    ...
# 3809  Uthiru, Naivasha road, Nairobi-Kenya
# 3810  Uthiru, Naivasha road, Nairobi-Kenya
# 3811  Uthiru, Naivasha road, Nairobi-Kenya
# 3812  Uthiru, Naivasha road, Nairobi-Kenya
# 3813  Uthiru, Naivasha road, Nairobi-Kenya
#
#                                    covv_subm_lab  \
# 18    International Livestock Research Institute
# 19    International Livestock Research Institute
# 20    International Livestock Research Institute
# 21    International Livestock Research Institute
# 1069  International Livestock Research Institute
# ...                                          ...
# 3809  International Livestock Research Institute
# 3810  International Livestock Research Institute
# 3811  International Livestock Research Institute
# 3812  International Livestock Research Institute
# 3813  International Livestock Research Institute
#
#                         covv_subm_lab_addr covv_subm_sample_id covv_authors  \
# 18    Uthiru, Naivasha road, Nairobi-Kenya           COVC01056
# 19    Uthiru, Naivasha road, Nairobi-Kenya           COVC01065
# 20    Uthiru, Naivasha road, Nairobi-Kenya           COVC01067
# 21    Uthiru, Naivasha road, Nairobi-Kenya           COVC01069
# 1069  Uthiru, Naivasha road, Nairobi-Kenya           COVC12481
# ...                                    ...                 ...          ...
# 3809  Uthiru, Naivasha road, Nairobi-Kenya          NPHL-12780
# 3810  Uthiru, Naivasha road, Nairobi-Kenya               NPHL1
# 3811  Uthiru, Naivasha road, Nairobi-Kenya               NPHL2
# 3812  Uthiru, Naivasha road, Nairobi-Kenya               NPHL3
# 3813  Uthiru, Naivasha road, Nairobi-Kenya               NPHL4
#
#      covv_comment comment_type
# 18
# 19
# 20
# 21
# 1069
# ...           ...          ...
# 3809
# 3810
# 3811
# 3812
# 3813
#
# [114 rows x 31 columns]

# %%
df_subf1.columns
# Out:
# Index(['S_NUM', 'AGE_YRS', 'GEND', 'DT_SAM_COLL', 'DT_SAM_RECEP',
#        'covv_location', 'submitter', 'fn', 'covv_virus_name', 'covv_type',
#        'covv_passage', 'covv_add_location', 'covv_host', 'covv_add_host_info',
#        'covv_sampling_strategy', 'covv_patient_status', 'covv_specimen',
#        'covv_outbreak', 'covv_last_vaccinated', 'covv_treatment',
#        'covv_seq_technology', 'covv_assembly_method', 'covv_coverage',
#        'covv_orig_lab', 'covv_orig_lab_addr', 'covv_subm_lab',
#        'covv_subm_lab_addr', 'covv_subm_sample_id', 'covv_authors',
#        'covv_comment', 'comment_type'],
#       dtype='object')

# %%
df_gisaid_sub = df_subf1[gisaid_header]#.drop('DT_SAM_COLL', axis=1)

# %%
df_gisaid_sub.head()
# Out:
#    submitter fn covv_virus_name        covv_type covv_passage DT_SAM_COLL  \
# 9                       hCoV-19  betacoronavirus     Original  2020-06-11
# 11                      hCoV-19  betacoronavirus     Original  2020-06-10
# 12                      hCoV-19  betacoronavirus     Original  2020-06-10
# 13                      hCoV-19  betacoronavirus     Original  2020-06-10
# 14                      hCoV-19  betacoronavirus     Original  2020-06-08
#
#    DT_SAM_RECEP         covv_location covv_add_location covv_host  ...  \
# 9           NaT  Africa/Kenya/Nairobi            Unkown     Human  ...
# 11          NaT  Africa/Kenya/Nairobi            Unkown     Human  ...
# 12          NaT  Africa/Kenya/Nairobi            Unkown     Human  ...
# 13          NaT  Africa/Kenya/Nairobi            Unkown     Human  ...
# 14   2020-06-14  Africa/Kenya/Nairobi            Unkown     Human  ...
#
#    covv_coverage                               covv_orig_lab  \
# 9                 International Livestock Research Institute
# 11                International Livestock Research Institute
# 12                International Livestock Research Institute
# 13                International Livestock Research Institute
# 14                International Livestock Research Institute
#
#                       covv_orig_lab_addr      S_NUM  \
# 9   Uthiru, Naivasha road, Nairobi-Kenya  COVC00854
# 11  Uthiru, Naivasha road, Nairobi-Kenya  COVC00867
# 12  Uthiru, Naivasha road, Nairobi-Kenya  COVC00893
# 13  Uthiru, Naivasha road, Nairobi-Kenya  COVC00915
# 14  Uthiru, Naivasha road, Nairobi-Kenya  COVC00962
#
#                                  covv_subm_lab  \
# 9   International Livestock Research Institute
# 11  International Livestock Research Institute
# 12  International Livestock Research Institute
# 13  International Livestock Research Institute
# 14  International Livestock Research Institute
#
#                       covv_subm_lab_addr covv_subm_sample_id covv_authors  \
# 9   Uthiru, Naivasha road, Nairobi-Kenya           COVC00854
# 11  Uthiru, Naivasha road, Nairobi-Kenya           COVC00867
# 12  Uthiru, Naivasha road, Nairobi-Kenya           COVC00893
# 13  Uthiru, Naivasha road, Nairobi-Kenya           COVC00915
# 14  Uthiru, Naivasha road, Nairobi-Kenya           COVC00962
#
#    covv_comment comment_type
# 9
# 11
# 12
# 13
# 14
#
# [5 rows x 31 columns]

# %%
# df_gisaid_sub_srt = df_gisaid_sub.assign(DT_SAM_COLL=df_gisaid_sub.sort_values('DT_SAM_COLL')['DT_SAM_COLL'].map(lambda x: x.strftime('%Y-%m-%d')))

# %%
df_gisaid_sub.head()
# Out:
#    submitter fn covv_virus_name        covv_type covv_passage DT_SAM_COLL  \
# 9                       hCoV-19  betacoronavirus     Original  2020-06-11
# 11                      hCoV-19  betacoronavirus     Original  2020-06-10
# 12                      hCoV-19  betacoronavirus     Original  2020-06-10
# 13                      hCoV-19  betacoronavirus     Original  2020-06-10
# 14                      hCoV-19  betacoronavirus     Original  2020-06-08
#
#    DT_SAM_RECEP         covv_location covv_add_location covv_host  ...  \
# 9           NaT  Africa/Kenya/Nairobi            Unkown     Human  ...
# 11          NaT  Africa/Kenya/Nairobi            Unkown     Human  ...
# 12          NaT  Africa/Kenya/Nairobi            Unkown     Human  ...
# 13          NaT  Africa/Kenya/Nairobi            Unkown     Human  ...
# 14   2020-06-14  Africa/Kenya/Nairobi            Unkown     Human  ...
#
#    covv_coverage                               covv_orig_lab  \
# 9                 International Livestock Research Institute
# 11                International Livestock Research Institute
# 12                International Livestock Research Institute
# 13                International Livestock Research Institute
# 14                International Livestock Research Institute
#
#                       covv_orig_lab_addr      S_NUM  \
# 9   Uthiru, Naivasha road, Nairobi-Kenya  COVC00854
# 11  Uthiru, Naivasha road, Nairobi-Kenya  COVC00867
# 12  Uthiru, Naivasha road, Nairobi-Kenya  COVC00893
# 13  Uthiru, Naivasha road, Nairobi-Kenya  COVC00915
# 14  Uthiru, Naivasha road, Nairobi-Kenya  COVC00962
#
#                                  covv_subm_lab  \
# 9   International Livestock Research Institute
# 11  International Livestock Research Institute
# 12  International Livestock Research Institute
# 13  International Livestock Research Institute
# 14  International Livestock Research Institute
#
#                       covv_subm_lab_addr covv_subm_sample_id covv_authors  \
# 9   Uthiru, Naivasha road, Nairobi-Kenya           COVC00854
# 11  Uthiru, Naivasha road, Nairobi-Kenya           COVC00867
# 12  Uthiru, Naivasha road, Nairobi-Kenya           COVC00893
# 13  Uthiru, Naivasha road, Nairobi-Kenya           COVC00915
# 14  Uthiru, Naivasha road, Nairobi-Kenya           COVC00962
#
#    covv_comment comment_type
# 9
# 11
# 12
# 13
# 14
#
# [5 rows x 31 columns]

# %%
df_gisaid_sub.shape
# Out:
# (858, 31)

# %%
df_brief_ids = pd.read_excel('/home/douso/Documents/TrendData/Results/ResultsMerged/all-brief-samples-IDs_30-08-2021.xlsx')[['SAMPLE']]

# %%
brief_id_list = list(df_brief_ids['SAMPLE'])

# %%
#DT_SAM_RECEP
gisaid_cols = ['submitter', 'fn', 'covv_virus_name', 'covv_type', 'covv_passage',
       'covv_collection_date', 'DT_SAM_RECEP','covv_location', 'covv_add_location',
       'covv_host', 'covv_add_host_info', 'covv_sampling_strategy',
       'covv_gender', 'covv_patient_age', 'covv_patient_status',
       'covv_specimen', 'covv_outbreak', 'covv_last_vaccinated',
       'covv_treatment', 'covv_seq_technology', 'covv_assembly_method',
       'covv_coverage', 'covv_orig_lab', 'covv_orig_lab_addr',
       'covv_provider_sample_id', 'covv_subm_lab', 'covv_subm_lab_addr',
       'covv_subm_sample_id', 'covv_authors', 'covv_comment', 'comment_type']

# %%
df_gisaid_sub.columns = gisaid_cols

# %%
df_gisaid_fin = df_gisaid_sub[df_gisaid_sub['covv_subm_sample_id'].isin(brief_id_list) == True]

# %%
df_gisaid_fin.shape
# Out:
# (758, 31)

# %%
df_gisaid_fin.head()
# Out:
#    submitter fn covv_virus_name        covv_type covv_passage  \
# 9                       hCoV-19  betacoronavirus     Original
# 11                      hCoV-19  betacoronavirus     Original
# 12                      hCoV-19  betacoronavirus     Original
# 13                      hCoV-19  betacoronavirus     Original
# 14                      hCoV-19  betacoronavirus     Original
#
#    covv_collection_date DT_SAM_RECEP         covv_location covv_add_location  \
# 9            2020-06-11          NaT  Africa/Kenya/Nairobi            Unkown
# 11           2020-06-10          NaT  Africa/Kenya/Nairobi            Unkown
# 12           2020-06-10          NaT  Africa/Kenya/Nairobi            Unkown
# 13           2020-06-10          NaT  Africa/Kenya/Nairobi            Unkown
# 14           2020-06-08   2020-06-14  Africa/Kenya/Nairobi            Unkown
#
#    covv_host  ... covv_coverage                               covv_orig_lab  \
# 9      Human  ...                International Livestock Research Institute
# 11     Human  ...                International Livestock Research Institute
# 12     Human  ...                International Livestock Research Institute
# 13     Human  ...                International Livestock Research Institute
# 14     Human  ...                International Livestock Research Institute
#
#                       covv_orig_lab_addr  covv_provider_sample_id  \
# 9   Uthiru, Naivasha road, Nairobi-Kenya                COVC00854
# 11  Uthiru, Naivasha road, Nairobi-Kenya                COVC00867
# 12  Uthiru, Naivasha road, Nairobi-Kenya                COVC00893
# 13  Uthiru, Naivasha road, Nairobi-Kenya                COVC00915
# 14  Uthiru, Naivasha road, Nairobi-Kenya                COVC00962
#
#                                  covv_subm_lab  \
# 9   International Livestock Research Institute
# 11  International Livestock Research Institute
# 12  International Livestock Research Institute
# 13  International Livestock Research Institute
# 14  International Livestock Research Institute
#
#                       covv_subm_lab_addr covv_subm_sample_id covv_authors  \
# 9   Uthiru, Naivasha road, Nairobi-Kenya           COVC00854
# 11  Uthiru, Naivasha road, Nairobi-Kenya           COVC00867
# 12  Uthiru, Naivasha road, Nairobi-Kenya           COVC00893
# 13  Uthiru, Naivasha road, Nairobi-Kenya           COVC00915
# 14  Uthiru, Naivasha road, Nairobi-Kenya           COVC00962
#
#    covv_comment comment_type
# 9
# 11
# 12
# 13
# 14
#
# [5 rows x 31 columns]

# %%
def my_date_parser(x):
    try:
        if type(x) == pd.Timestamp:
            x = x#.strftime('%d-%m-%Y')
        if type(x) != pd.Timestamp and type(x) != (int, float, pd.NaT):
            x = pd.to_datetime(x, errors='ignore', dayfirst=True)#.strftime('%d-%m-%Y')
        if x in ['None indicated', 'NIL', 'Not indicated on form ',
                    'Nil', 'None indicated', 'Leaked Sample - Empty', 'nan']:
            x = pd.NaT
    except (ValueError, AttributeError):
        x = pd.NaT
    return x

# %%
df_gisaid_fin = df_gisaid_fin.assign(covv_collection_date=df_gisaid_fin['covv_collection_date'].apply(lambda x: my_date_parser(x)))

# %%
df_gisaid_fin.sort_values(['covv_collection_date']).to_excel(f'/home/douso/Documents/TrendData/Results/ResultsMerged/gisaid_data_{dt}.xlsx', index=False)

# %% [raw]
# sbatch -p batch -J sra_dwnld -n 30 --qos vip --mail-user=d.ouso@cgiar.org --mail-user=zeusfranck07yahoo.com --mail-type=BEGIN --mail-type=END -w compute05 sra.sh
