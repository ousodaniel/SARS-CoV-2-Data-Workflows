# %% [markdown]
# ## GISAID Metadata preparation

# %%
import pandas as pd
import numpy as np
import glob, os, re
from datetime import  datetime

# %%
dt = datetime.today().strftime(format='%d-%m-%Y')
ref = 'seq16-21'

# %% [markdown]
# ### **Establish parent directory**

# %%
#uniqueness in directory and file names is assumed for all analyses
sars_dir = "SARS-CoV-2"
home_dir = os.getenv('HOME')
parent_dir = glob.glob(f'{home_dir}/**/{sars_dir}', recursive=True)[0]

# %% [markdown]
# ### Load submission form

# %%
df_gisaid = pd.read_excel(glob.glob(f'{parent_dir}/**/20210222_EpiCoV.xls', recursive=True)[0], 'Submissions')

# %%
df_gisaid.head()
# Out:
#          submitter                   fn                  covv_virus_name  \
# 0        Submitter       FASTA filename                       Virus name
# 1  GISAID username  all_sequences.fasta  hCoV-19/Country/Identifier/2020
#
#          covv_type             covv_passage covv_collection_date  \
# 0             Type  Passage details/history      Collection date
# 1  betacoronavirus      e.g. Original, Vero           2020-03-02
#
#                        covv_location  \
# 0                           Location
# 1  e.g. Continent / Country / Region
#
#                                   covv_add_location  \
# 0                   Additional location information
# 1  e.g. Cruise Ship, Convention, Live animal market
#
#                                            covv_host  \
# 0                                               Host
# 1  e.g. Human, Animal, Environment, Laboratory de...
#
#                               covv_add_host_info  ...  \
# 0                    Additional host information  ...
# 1  e.g. Patient infected while traveling in ….    ...
#
#                          covv_coverage  \
# 0                             Coverage
# 1  e.g. 70x, 1,000x, 10,000x (average)
#
#                                        covv_orig_lab covv_orig_lab_addr  \
# 0                                    Originating lab            Address
# 1  Where the clinical specimen or virus isolate w...                NaN
#
#                      covv_provider_sample_id  \
# 0  Sample ID given by originating laboratory
# 1                                        NaN
#
#                                        covv_subm_lab covv_subm_lab_addr  \
# 0                                     Submitting lab            Address
# 1  Where sequence data have been generated and su...                NaN
#
#                             covv_subm_sample_id             covv_authors  \
# 0  Sample ID given by the submitting laboratory                  Authors
# 1                                           NaN  e.g. Jane Doe, John Doe
#
#   covv_comment  comment_type
# 0      Comment  Comment Icon
# 1          NaN           NaN
#
# [2 rows x 30 columns]

# %%
df_gisaid.columns
# Out:
# Index(['submitter', 'fn', 'covv_virus_name', 'covv_type', 'covv_passage',
#        'covv_collection_date', 'covv_location', 'covv_add_location',
#        'covv_host', 'covv_add_host_info', 'covv_sampling_strategy',
#        'covv_gender', 'covv_patient_age', 'covv_patient_status',
#        'covv_specimen', 'covv_outbreak', 'covv_last_vaccinated',
#        'covv_treatment', 'covv_seq_technology', 'covv_assembly_method',
#        'covv_coverage', 'covv_orig_lab', 'covv_orig_lab_addr',
#        'covv_provider_sample_id', 'covv_subm_lab', 'covv_subm_lab_addr',
#        'covv_subm_sample_id', 'covv_authors', 'covv_comment', 'comment_type'],
#       dtype='object')

# %%
gisaid_header = ['submitter', 'fn', 'covv_virus_name', 'covv_type', 'covv_passage', 'DT_SAM_COLL', 
 'DT_SAM_RECEP', 'covv_location', 'covv_add_location','covv_host', 'covv_add_host_info', 'covv_sampling_strategy',
 'GEND', 'AGE_YRS', 'covv_patient_status', 'covv_specimen', 'covv_outbreak', 
 'covv_last_vaccinated', 'covv_treatment', 'covv_seq_technology', 'covv_assembly_method', 'covv_coverage', 
 'covv_orig_lab', 'covv_orig_lab_addr', 'S_NUM', 'covv_subm_lab', 'covv_subm_lab_addr', 
 'covv_subm_sample_id', 'covv_authors', 'covv_comment', 'comment_type']

# %% [markdown]
# ### **Pull-in the metadata**

# %%
df_metadata = pd.read_excel(glob.glob(f'{parent_dir}/**/COVID19-resultsCts-merged-cln.xlsx', recursive=True)[0])

# %%
#get the columns necessary
df_headers = df_metadata[['S_NUM', 'AGE_YRS', 'GEND', 'NAT', 
           'COUNT_RES',  
           'DT_SAM_COLL', 
           'DT_SAM_RECEP']]

# %%
df_gisaid_all = pd.read_excel(glob.glob(f'{parent_dir}/**/seq-summary-metadata_seq16-21_gsaid_01-11-2021.xlsx')[0], usecols=['sequence_name'])

# %%
df_gisaid_all.head
# Out:
# <bound method NDFrame.head of     sequence_name
# 0       COVC24477
# 1       COVC24478
# 2       COVC24479
# 3       COVC24480
# 4       COVC24481
# ..            ...
# 828     COVM01412
# 829     COVM01413
# 830     COVM01415
# 831     COVM01416
# 832     COVM01417
#
# [833 rows x 1 columns]>

# %%
df_mrgl = df_gisaid_all.merge(df_headers, how='left', left_on='sequence_name', right_on='S_NUM').drop('sequence_name', axis=1)
df_mrgl.shape
# Out:
# (833, 7)

# %% [raw]
# df_mrgi = df_gisaid_all.merge(df_headers, how='inner', left_on='sequence_name', right_on='S_NUM')

# %% [raw]
# set(df_mrgl['sequence_name']) - set(df_mrgi['sequence_name'])#.shape#head()

# %% [raw]
# {'COVC28286',
#  'MoH-Cov-1',
#  'MoH-Cov-2',
#  'MoH-Cov-3',
#  'MoH-Cov-4',
#  'MoH-Cov-5',
#  'NHRL-N003',
#  'NHRL-N004',
#  'NHRL-N007',
#  'NHRL-N009',
#  'NHRL-N012',
#  'NHRL-N021',
#  'NHRL-N022',
#  'NHRL-N024',
#  'NHRL-N031',
#  'NHRL-N036'}
# sed -i -e 's/>COVC28286/>COVC23286/' -e 's/MoH-Cov/MOH-COV/g' gisaid_all.fasta

# %%
df_mrgl.head()
# Out:
#        S_NUM  AGE_YRS GEND    NAT COUNT_RES DT_SAM_COLL DT_SAM_RECEP
# 0  COVC24477     80.0    F  Kenya   Nyamira  2021-09-18   2021-09-21
# 1  COVC24478     76.0    F  Kenya   Nyamira  2021-09-19   2021-09-21
# 2  COVC24479     60.0    F  Kenya   Nyamira  2021-09-20   2021-09-21
# 3  COVC24480     36.0    F  Kenya   Nyamira  2021-09-20   2021-09-21
# 4  COVC24481     61.0    F  Kenya   Nyamira  2021-09-18   2021-09-21

# %% [markdown]
# ### **Be sure the next input is update**

# %%
df_seq_summ = pd.read_excel(glob.glob(f'{parent_dir}/**/seq-summary-metadata_seq16-21_gsaid_01-11-2021.xlsx')[0])
df_seq_summ.shape
# Out:
# (833, 10)

# %%
df_seqd_int = df_seq_summ.sort_values(['sequence_name', 'genome_coverage']).drop_duplicates('sequence_name', keep='last')
df_seqd_int.shape#.head()
# Out:
# (833, 10)

# %% [raw]
# #Filter service samples; remain with internals only
# df_seqd_int = df_seq_summ[df_seq_summ['sequence_name'].str.contains('KEM') == False]#.head()

# %%
df_seqd_int.shape
# Out:
# (833, 10)

# %%
df_seqd_int.head()
# Out:
#     sequence_name clade lineage  genome_coverage    run_num tech      seq_dt  \
# 480     COVC17732   20C     B.1             92.4  Run16_ONT  ONT  15-09-2021
# 481     COVC17734   20C     B.1             91.4  Run16_ONT  ONT  15-09-2021
# 482     COVC17735   20C     B.1             94.2  Run16_ONT  ONT  15-09-2021
# 483     COVC17737   20C     B.1             91.5  Run16_ONT  ONT  15-09-2021
# 484     COVC17739   20C     B.1             97.2  Run16_ONT  ONT  15-09-2021
#
#     lib_prep primer_set  sno.
# 480  NEBNext   ARTIC_V3  1967
# 481  NEBNext   ARTIC_V3  1968
# 482  NEBNext   ARTIC_V3  1969
# 483  NEBNext   ARTIC_V3  1970
# 484  NEBNext   ARTIC_V3  1971

# %% [raw]
# #Merge metadata with seq summary data
# df_seq_metar = df_seqd_int.set_index('sequence_name').merge(df_mrgl.set_index('S_NUM'), how='right', left_index=True, right_index=True)
# df_seq_metar.shape

# %%
#Merge metadata with seq summary data
df_seq_meta_on = df_mrgl.merge(df_seqd_int, how='left', left_on='S_NUM', right_on='sequence_name')
df_seq_meta_on.shape
# Out:
# (833, 17)

# %%
mask = df_seq_meta_on.duplicated('sequence_name', keep=False)
df_seq_meta_on[mask == True]
# Out:
# Empty DataFrame
# Columns: [S_NUM, AGE_YRS, GEND, NAT, COUNT_RES, DT_SAM_COLL, DT_SAM_RECEP, sequence_name, clade, lineage, genome_coverage, run_num, tech, seq_dt, lib_prep, primer_set, sno.]
# Index: []

# %%
df_seq_meta_on.head()
# Out:
#        S_NUM  AGE_YRS GEND    NAT COUNT_RES DT_SAM_COLL DT_SAM_RECEP  \
# 0  COVC24477     80.0    F  Kenya   Nyamira  2021-09-18   2021-09-21
# 1  COVC24478     76.0    F  Kenya   Nyamira  2021-09-19   2021-09-21
# 2  COVC24479     60.0    F  Kenya   Nyamira  2021-09-20   2021-09-21
# 3  COVC24480     36.0    F  Kenya   Nyamira  2021-09-20   2021-09-21
# 4  COVC24481     61.0    F  Kenya   Nyamira  2021-09-18   2021-09-21
#
#   sequence_name        clade lineage  genome_coverage   run_num      tech  \
# 0     COVC24477  21J (Delta)  AY.7.1             95.6  Run18_NS  Illumina
# 1     COVC24478  21J (Delta)    AY.4             96.4  Run18_NS  Illumina
# 2     COVC24479  21J (Delta)  AY.7.1             88.5  Run18_NS  Illumina
# 3     COVC24480  21A (Delta)   AY.16             96.7  Run18_NS  Illumina
# 4     COVC24481  21A (Delta)   AY.16             94.6  Run18_NS  Illumina
#
#        seq_dt    lib_prep primer_set  sno.
# 0  10-10-2021  NEBNext_FS   ARTIC_V3  1487
# 1  10-10-2021  NEBNext_FS   ARTIC_V3  1488
# 2  10-10-2021  NEBNext_FS   ARTIC_V3  1489
# 3  10-10-2021  NEBNext_FS   ARTIC_V3  1490
# 4  10-10-2021  NEBNext_FS   ARTIC_V3  1491

# %%
#Merge metadata with seq summary data
df_seq_metal = df_mrgl.set_index('S_NUM').merge(df_seqd_int.set_index('sequence_name'), how='left', left_index=True, right_index=True)
df_seq_metal.shape
# Out:
# (833, 15)

# %% [raw]
# len(set(df_seq_metal.index) & set(df_seq_metai.index))#.shape#head()

# %%
def get_seq_tech(x):
    x = str(x)
    if 'ONT' in x:
        return x.replace(x, 'MinION')
    elif '_NS' in x:
        return x.replace(x, 'NextSeq')
    return x.replace(x, 'MiSeq')

# %%
df_seq_meta2 = df_seq_metal.assign(covv_seq_technology = df_seq_metal['run_num']
                                  .apply(lambda x: get_seq_tech(x)))

# %%
df_seq_meta2.shape
# Out:
# (833, 16)

# %%
df_seq_meta2.head()
# Out:
#            AGE_YRS GEND    NAT COUNT_RES DT_SAM_COLL DT_SAM_RECEP  \
# S_NUM
# COVC24477     80.0    F  Kenya   Nyamira  2021-09-18   2021-09-21
# COVC24478     76.0    F  Kenya   Nyamira  2021-09-19   2021-09-21
# COVC24479     60.0    F  Kenya   Nyamira  2021-09-20   2021-09-21
# COVC24480     36.0    F  Kenya   Nyamira  2021-09-20   2021-09-21
# COVC24481     61.0    F  Kenya   Nyamira  2021-09-18   2021-09-21
#
#                  clade lineage  genome_coverage   run_num      tech  \
# S_NUM
# COVC24477  21J (Delta)  AY.7.1             95.6  Run18_NS  Illumina
# COVC24478  21J (Delta)    AY.4             96.4  Run18_NS  Illumina
# COVC24479  21J (Delta)  AY.7.1             88.5  Run18_NS  Illumina
# COVC24480  21A (Delta)   AY.16             96.7  Run18_NS  Illumina
# COVC24481  21A (Delta)   AY.16             94.6  Run18_NS  Illumina
#
#                seq_dt    lib_prep primer_set  sno. covv_seq_technology
# S_NUM
# COVC24477  10-10-2021  NEBNext_FS   ARTIC_V3  1487             NextSeq
# COVC24478  10-10-2021  NEBNext_FS   ARTIC_V3  1488             NextSeq
# COVC24479  10-10-2021  NEBNext_FS   ARTIC_V3  1489             NextSeq
# COVC24480  10-10-2021  NEBNext_FS   ARTIC_V3  1490             NextSeq
# COVC24481  10-10-2021  NEBNext_FS   ARTIC_V3  1491             NextSeq

# %%
df_seq_meta3 = df_seq_meta2.assign(covv_location = 'Africa/' + df_seq_meta2['NAT'] + '/' + df_seq_meta2['COUNT_RES'])

# %%
df_seq_meta3.shape
# Out:
# (833, 17)

# %%
df_subf = df_seq_meta3

# %%
submitter = 'Soyola'
fn = 'gisaid_all.fasta'
cvn = 'hCoV-19/Kenya/ILRI_'
vt = 'betacoronavirus'
cp = 'Original'
cal = 'unknown'
ch = 'Human'
cahi = 'unknown'
css = 'Surveillance'
cps = 'unknown'
cps = 'unknown'
cs = 'NP Swab'
co = 'unknown'
clv = 'unknown'
ct = 'unknown'
# cst = 'Illumina'
cam = 'Consensus'
cc = 'unknown'
col = 'International Livestock Research Institute'
cola = 'Uthiru, Naivasha road, Nairobi-Kenya'
# cpsi = 'ILRI'
csl = 'International Livestock Research Institute'
csla = 'Uthiru, Naivasha road, Nairobi-Kenya'
cssi = df_subf.index.tolist()
ca = 'Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, Shebbar Osiany, Edward Kiritu, Paul Dobi, Collins Muli, Patrick Amoth, Vishvanath Nene, Sonal P. Henson, Edward O. Abworo'
ccomm = ''
ct = ''

# %%
df_subf['submitter'] = submitter
df_subf['fn'] = fn
df_subf['covv_virus_name'] = cvn
df_subf['covv_type'] = vt
df_subf['covv_passage'] = cp
df_subf['covv_add_location'] = cal
df_subf['covv_host'] = ch
df_subf['covv_add_host_info'] = cahi
df_subf['covv_sampling_strategy'] = css
df_subf['covv_patient_status'] = cps
df_subf['covv_specimen'] = cs
df_subf['covv_outbreak'] = co
df_subf['covv_last_vaccinated'] = clv
df_subf['covv_treatment'] = ct
# df_subf['covv_seq_technology'] = cst
df_subf['covv_assembly_method'] = cam
df_subf['covv_coverage'] = cc
df_subf['covv_orig_lab'] = col
df_subf['covv_orig_lab_addr'] = cola
# df_subf['covv_provider_sample_id'] = cpsi
df_subf['covv_subm_lab'] = csl
df_subf['covv_subm_lab_addr'] = csla
df_subf['covv_subm_sample_id'] = cssi
df_subf['covv_authors'] = ca
df_subf['covv_comment'] = ccomm
df_subf['comment_type'] = ct
df_subf.shape
# Out:
# (833, 41)

# %%
df_subf.columns
# Out:
# Index(['AGE_YRS', 'GEND', 'NAT', 'COUNT_RES', 'DT_SAM_COLL', 'DT_SAM_RECEP',
#        'clade', 'lineage', 'genome_coverage', 'run_num', 'tech', 'seq_dt',
#        'lib_prep', 'primer_set', 'sno.', 'covv_seq_technology',
#        'covv_location', 'submitter', 'fn', 'covv_virus_name', 'covv_type',
#        'covv_passage', 'covv_add_location', 'covv_host', 'covv_add_host_info',
#        'covv_sampling_strategy', 'covv_patient_status', 'covv_specimen',
#        'covv_outbreak', 'covv_last_vaccinated', 'covv_treatment',
#        'covv_assembly_method', 'covv_coverage', 'covv_orig_lab',
#        'covv_orig_lab_addr', 'covv_subm_lab', 'covv_subm_lab_addr',
#        'covv_subm_sample_id', 'covv_authors', 'covv_comment', 'comment_type'],
#       dtype='object')

# %%
df_subf1 = df_subf.drop(['NAT', 'COUNT_RES'], axis=1)

# %%
df_filter80 = df_subf1[df_subf1['genome_coverage'] >= 80.0]#.fillna('unknown')

# %%
df_filter80.shape
# Out:
# (685, 39)

# %%
df_filter80.columns
# Out:
# Index(['AGE_YRS', 'GEND', 'DT_SAM_COLL', 'DT_SAM_RECEP', 'clade', 'lineage',
#        'genome_coverage', 'run_num', 'tech', 'seq_dt', 'lib_prep',
#        'primer_set', 'sno.', 'covv_seq_technology', 'covv_location',
#        'submitter', 'fn', 'covv_virus_name', 'covv_type', 'covv_passage',
#        'covv_add_location', 'covv_host', 'covv_add_host_info',
#        'covv_sampling_strategy', 'covv_patient_status', 'covv_specimen',
#        'covv_outbreak', 'covv_last_vaccinated', 'covv_treatment',
#        'covv_assembly_method', 'covv_coverage', 'covv_orig_lab',
#        'covv_orig_lab_addr', 'covv_subm_lab', 'covv_subm_lab_addr',
#        'covv_subm_sample_id', 'covv_authors', 'covv_comment', 'comment_type'],
#       dtype='object')

# %%
df_gisaid_sub = df_filter80.reset_index().rename(columns={'index': 'S_NUM'})[gisaid_header] #.drop('DT_SAM_COLL', axis=1)

# %%
df_gisaid_sub.head()
# Out:
#   submitter                fn      covv_virus_name        covv_type  \
# 0    Soyola  gisaid_all.fasta  hCoV-19/Kenya/ILRI_  betacoronavirus
# 1    Soyola  gisaid_all.fasta  hCoV-19/Kenya/ILRI_  betacoronavirus
# 2    Soyola  gisaid_all.fasta  hCoV-19/Kenya/ILRI_  betacoronavirus
# 3    Soyola  gisaid_all.fasta  hCoV-19/Kenya/ILRI_  betacoronavirus
# 4    Soyola  gisaid_all.fasta  hCoV-19/Kenya/ILRI_  betacoronavirus
#
#   covv_passage DT_SAM_COLL DT_SAM_RECEP         covv_location  \
# 0     Original  2021-09-18   2021-09-21  Africa/Kenya/Nyamira
# 1     Original  2021-09-19   2021-09-21  Africa/Kenya/Nyamira
# 2     Original  2021-09-20   2021-09-21  Africa/Kenya/Nyamira
# 3     Original  2021-09-20   2021-09-21  Africa/Kenya/Nyamira
# 4     Original  2021-09-18   2021-09-21  Africa/Kenya/Nyamira
#
#   covv_add_location covv_host  ... covv_coverage  \
# 0           unknown     Human  ...       unknown
# 1           unknown     Human  ...       unknown
# 2           unknown     Human  ...       unknown
# 3           unknown     Human  ...       unknown
# 4           unknown     Human  ...       unknown
#
#                                 covv_orig_lab  \
# 0  International Livestock Research Institute
# 1  International Livestock Research Institute
# 2  International Livestock Research Institute
# 3  International Livestock Research Institute
# 4  International Livestock Research Institute
#
#                      covv_orig_lab_addr      S_NUM  \
# 0  Uthiru, Naivasha road, Nairobi-Kenya  COVC24477
# 1  Uthiru, Naivasha road, Nairobi-Kenya  COVC24478
# 2  Uthiru, Naivasha road, Nairobi-Kenya  COVC24479
# 3  Uthiru, Naivasha road, Nairobi-Kenya  COVC24480
# 4  Uthiru, Naivasha road, Nairobi-Kenya  COVC24481
#
#                                 covv_subm_lab  \
# 0  International Livestock Research Institute
# 1  International Livestock Research Institute
# 2  International Livestock Research Institute
# 3  International Livestock Research Institute
# 4  International Livestock Research Institute
#
#                      covv_subm_lab_addr covv_subm_sample_id  \
# 0  Uthiru, Naivasha road, Nairobi-Kenya           COVC24477
# 1  Uthiru, Naivasha road, Nairobi-Kenya           COVC24478
# 2  Uthiru, Naivasha road, Nairobi-Kenya           COVC24479
# 3  Uthiru, Naivasha road, Nairobi-Kenya           COVC24480
# 4  Uthiru, Naivasha road, Nairobi-Kenya           COVC24481
#
#                                         covv_authors covv_comment comment_type
# 0  Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
# 1  Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
# 2  Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
# 3  Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
# 4  Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
#
# [5 rows x 31 columns]

# %%
# df_gisaid_sub_srt = df_gisaid_sub.assign(DT_SAM_COLL=df_gisaid_sub.sort_values('DT_SAM_COLL')['DT_SAM_COLL'].map(lambda x: x.strftime('%Y-%m-%d')))

# %%
df_gisaid_sub.columns
# Out:
# Index(['submitter', 'fn', 'covv_virus_name', 'covv_type', 'covv_passage',
#        'DT_SAM_COLL', 'DT_SAM_RECEP', 'covv_location', 'covv_add_location',
#        'covv_host', 'covv_add_host_info', 'covv_sampling_strategy', 'GEND',
#        'AGE_YRS', 'covv_patient_status', 'covv_specimen', 'covv_outbreak',
#        'covv_last_vaccinated', 'covv_treatment', 'covv_seq_technology',
#        'covv_assembly_method', 'covv_coverage', 'covv_orig_lab',
#        'covv_orig_lab_addr', 'S_NUM', 'covv_subm_lab', 'covv_subm_lab_addr',
#        'covv_subm_sample_id', 'covv_authors', 'covv_comment', 'comment_type'],
#       dtype='object')

# %% [markdown]
# ### **Confirm the following input file is update**

# %% [raw]
# df_brief_ids = pd.read_excel('/home/douso/Documents/TrendData/Results/ResultsMerged/all-brief-samples-IDs_07-09-2021.xlsx')[['SAMPLE']]

# %% [raw]
# brief_id_list = list(df_brief_ids[df_brief_ids['SAMPLE'].str.contains('KEM') == False]['SAMPLE'])

# %%
#DT_SAM_RECEP
gisaid_cols = ['submitter', 'fn', 'covv_virus_name', 'covv_type', 'covv_passage',
       'covv_collection_date', 'DT_SAM_RECEP','covv_location', 'covv_add_location',
       'covv_host', 'covv_add_host_info', 'covv_sampling_strategy',
       'covv_gender', 'covv_patient_age', 'covv_patient_status',
       'covv_specimen', 'covv_outbreak', 'covv_last_vaccinated',
       'covv_treatment', 'covv_seq_technology', 'covv_assembly_method',
       'covv_coverage', 'covv_orig_lab', 'covv_orig_lab_addr',
       'covv_provider_sample_id', 'covv_subm_lab', 'covv_subm_lab_addr',
       'covv_subm_sample_id', 'covv_authors', 'covv_comment', 'comment_type']

# %%
df_gisaid_sub.columns = gisaid_cols

# %%
df_dt = df_gisaid_sub[df_gisaid_sub['covv_collection_date'].isna() == False]
df_dt_fmt = df_dt.assign(covv_collection_date=df_dt['covv_collection_date'].dt.strftime('%Y-%m-%d'))
df_missing_dt = df_gisaid_sub[df_gisaid_sub['covv_collection_date'].isna() == True]

# %%
df_missing_dt_corr = df_missing_dt.assign(covv_collection_date=df_missing_dt['DT_SAM_RECEP'].apply(lambda x: pd.Timestamp(x).strftime('%Y-%m') if (isinstance(x, pd.Timestamp)) else x.replace(x, pd.NaT)))

# %%
df_gisaid_fin = df_dt_fmt.append(df_missing_dt_corr)

# %%
df_gisaid_fin.shape
# Out:
# (685, 31)

# %% [raw]
# df_gisaid_fin = df_gisaid_fin.assign(covv_collection_date=df_gisaid_fin['covv_collection_date'].apply(lambda x: my_date_parser(x)))

# %%
df_prev_sub = pd.read_excel(glob.glob(f'{parent_dir}/**/Submissions/20210914_ILRI_gisaid_submission_metadata_curated.xls')[0], sheet_name='Submissions', usecols=['covv_provider_sample_id'])

# %%
df_gisaid_fil = df_gisaid_fin[df_gisaid_fin['covv_provider_sample_id'].isin(df_prev_sub.covv_provider_sample_id) == False].fillna('unknown') 

df_gisaid_fil.to_excel(f"{glob.glob(f'{parent_dir}/Gisaid')[0]}/gisaid_data_{ref}_{dt}.xlsx", index=False)

pd.Series(df_gisaid_fil['covv_provider_sample_id']).to_csv(f"{glob.glob(f'{parent_dir}/Gisaid')[0]}/gisaid_IDs_{ref}_{dt}.csv", index=False, header=False)

df_gisaid_fil.shape
# Out:
# (685, 31)

# %%
df_gisaid_fil.to_csv

# %% [raw]
# df_final = pd.read_excel(glob.glob(f'{parent_dir}/**/Submissions/20210914_ILRI_gisaid_submission_metadata.xls')[0], sheet_name='Submissions')
# # final.columns
# final['covv_seq_technology'].value_counts()

# %%
df_final_feedB = pd.read_excel(glob.glob(f'{parent_dir}/**/Submissions/20210914_ILRI_gisaid_submission_metadata_curated.xls')[0], sheet_name='Submissions')
df_final_feedB['covv_seq_technology'].value_counts()
# Out:
# NextSeq                  55
# MiSeq                    39
# Minion                   10
# Sequencing technology     1
# Name: covv_seq_technology, dtype: int64

# %%
final.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 732 entries, 0 to 731
# Data columns (total 30 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   submitter                732 non-null    object
#  1   fn                       732 non-null    object
#  2   covv_virus_name          732 non-null    object
#  3   covv_type                732 non-null    object
#  4   covv_passage             732 non-null    object
#  5   covv_collection_date     732 non-null    object
#  6   covv_location            732 non-null    object
#  7   covv_add_location        732 non-null    object
#  8   covv_host                732 non-null    object
#  9   covv_add_host_info       732 non-null    object
#  10  covv_sampling_strategy   732 non-null    object
#  11  covv_gender              732 non-null    object
#  12  covv_patient_age         732 non-null    object
#  13  covv_patient_status      732 non-null    object
#  14  covv_specimen            732 non-null    object
#  15  covv_outbreak            732 non-null    object
#  16  covv_last_vaccinated     732 non-null    object
#  17  covv_treatment           1 non-null      object
#  18  covv_seq_technology      732 non-null    object
#  19  covv_assembly_method     732 non-null    object
#  20  covv_coverage            732 non-null    object
#  21  covv_orig_lab            732 non-null    object
#  22  covv_orig_lab_addr       732 non-null    object
#  23  covv_provider_sample_id  732 non-null    object
#  24  covv_subm_lab            732 non-null    object
#  25  covv_subm_lab_addr       732 non-null    object
#  26  covv_subm_sample_id      732 non-null    object
#  27  covv_authors             732 non-null    object
#  28  covv_comment             1 non-null      object
#  29  comment_type             1 non-null      object
# dtypes: object(30)
# memory usage: 171.7+ KB

# %% [markdown]
# ### **Get genome coverage data from nextclade output**

# %%
df_nxt_ill = pd.read_csv(glob.glob(f'{parent_dir}/**/Illumina/transposed_report.tsv')[0], sep='\t')

# %%
df_nxt_ill.head(12)
# Out:
#                    Assembly  # contigs (>= 0 bp)  # contigs (>= 1000 bp)  \
# 0    COCV11310_S6.consensus                    1                       1
# 1   COVC03617_S74.consensus                    1                       1
# 2   COVC03665_S75.consensus                    1                       1
# 3   COVC03696_S76.consensus                    1                       1
# 4   COVC03723_S77.consensus                    1                       1
# 5   COVC03813_S78.consensus                    1                       1
# 6   COVC03955_S79.consensus                    1                       1
# 7   COVC03960_S80.consensus                    1                       1
# 8   COVC03965_S81.consensus                    1                       1
# 9   COVC03977_S82.consensus                    1                       1
# 10  COVC03982_S83.consensus                    1                       1
# 11  COVC03989_S84.consensus                    1                       1
#
#     # contigs (>= 5000 bp)  # contigs (>= 10000 bp)  # contigs (>= 25000 bp)  \
# 0                        1                        1                        1
# 1                        1                        1                        1
# 2                        1                        1                        1
# 3                        1                        1                        1
# 4                        1                        1                        1
# 5                        1                        1                        1
# 6                        1                        1                        1
# 7                        1                        1                        1
# 8                        1                        1                        1
# 9                        1                        1                        1
# 10                       1                        1                        1
# 11                       1                        1                        1
#
#     # contigs (>= 50000 bp)  Total length (>= 0 bp)  \
# 0                         0                   29903
# 1                         0                   29903
# 2                         0                   29903
# 3                         0                   29903
# 4                         0                   29903
# 5                         0                   29903
# 6                         0                   29903
# 7                         0                   29903
# 8                         0                   29903
# 9                         0                   29903
# 10                        0                   29903
# 11                        0                   29903
#
#     Total length (>= 1000 bp)  Total length (>= 5000 bp)  ...  \
# 0                       29903                      29903  ...
# 1                       29903                      29903  ...
# 2                       29903                      29903  ...
# 3                       29903                      29903  ...
# 4                       29903                      29903  ...
# 5                       29903                      29903  ...
# 6                       29903                      29903  ...
# 7                       29903                      29903  ...
# 8                       29903                      29903  ...
# 9                       29903                      29903  ...
# 10                      29903                      29903  ...
# 11                      29903                      29903  ...
#
#     Largest alignment  Total aligned length   NA50  NGA50   NA75  NGA75  LA50  \
# 0               17906                 17906  17906  17906      -      -     1
# 1               29487                 29487  29487  29487  29487  29487     1
# 2               29300                 29300  29300  29300  29300  29300     1
# 3               29511                 29511  29511  29511  29511  29511     1
# 4               29667                 29667  29667  29667  29667  29667     1
# 5               29275                 29275  29275  29275  29275  29275     1
# 6               29487                 29487  29487  29487  29487  29487     1
# 7               29487                 29487  29487  29487  29487  29487     1
# 8               29275                 29275  29275  29275  29275  29275     1
# 9               29487                 29487  29487  29487  29487  29487     1
# 10              29275                 29275  29275  29275  29275  29275     1
# 11              29259                 29259  29259  29259  29259  29259     1
#
#     LGA50  LA75  LGA75
# 0       1     -      -
# 1       1     1      1
# 2       1     1      1
# 3       1     1      1
# 4       1     1      1
# 5       1     1      1
# 6       1     1      1
# 7       1     1      1
# 8       1     1      1
# 9       1     1      1
# 10      1     1      1
# 11      1     1      1
#
# [12 rows x 52 columns]

# %%
df_nxt_ill_gcov = df_nxt_ill[['Assembly', 'Genome fraction (%)']]

# %%
df_nxt_ill_gcov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 952 entries, 0 to 951
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Assembly             952 non-null    object
#  1   Genome fraction (%)  952 non-null    object
# dtypes: object(2)
# memory usage: 15.0+ KB

# %%
def clean(x):
    if float(x) and x != '-':
        return round(float(x), 1)
    else:
        return np.NaN

# %%
#get sample ids only and rounded genome coverage
p = re.compile("_S[1-9]{0,3}\w.*")
new_ass = df_nxt_ill_gcov['Assembly'].apply(lambda x: p.sub('', x))
new_gen_cov = df_nxt_ill_gcov['Genome fraction (%)'].replace('-', np.NaN).apply(lambda x: clean(x))

# %%
new_ass
# Out:
# 0       COCV11310
# 1       COVC03617
# 2       COVC03665
# 3       COVC03696
# 4       COVC03723
#           ...
# 947    NPHL_12780
# 948         NPHL1
# 949         NPHL2
# 950         NPHL3
# 951         NPHL4
# Name: Assembly, Length: 952, dtype: object

# %%
new_gen_cov
# Out:
# 0      59.9
# 1      98.6
# 2      98.0
# 3      98.7
# 4      99.2
#        ...
# 947    26.9
# 948    99.0
# 949    74.7
# 950    98.1
# 951    61.0
# Name: Genome fraction (%), Length: 952, dtype: float64

# %%
df_nxt_ill_gcov_curated = pd.DataFrame({'sample_id': new_ass, 'genome_cov': new_gen_cov})

# %%
df_nxt_ill_gcov_curated[df_nxt_ill_gcov_curated['genome_cov'] >= 80.0].to_excel(glob.glob(f'{parent_dir}/**/Gisaid/Illumina/Illumina-genome-coverage80.xlsx')[0], index=False)

# %%
df_nxt_ont = pd.read_csv(glob.glob(f'{parent_dir}/**/Gisaid/ONT/transposed_report.tsv')[0], sep='\t')

# %%
df_nxt_ont_gcov = df_nxt_ont[['Assembly', 'Genome fraction (%)']]

# %%
df_nxt_ont_gcov.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 952 entries, 0 to 951
# Data columns (total 2 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   Assembly             952 non-null    object
#  1   Genome fraction (%)  952 non-null    object
# dtypes: object(2)
# memory usage: 15.0+ KB

# %%
#get sample ids only and rounded genome coverage
p = re.compile("_S[1-9]{0,3}\w.*")
new_ass_ont = df_nxt_ont_gcov['Assembly'].apply(lambda x: p.sub('', x))
new_gen_cov_ont = df_ont_gcov['Genome fraction (%)'].replace('-', np.NaN).apply(lambda x: clean(x))

# %%
new_ass_ont
# Out:
# 0       COCV11310
# 1       COVC03617
# 2       COVC03665
# 3       COVC03696
# 4       COVC03723
#           ...
# 947    NPHL_12780
# 948         NPHL1
# 949         NPHL2
# 950         NPHL3
# 951         NPHL4
# Name: Assembly, Length: 952, dtype: object

# %%
new_gen_cov_ont
# Out:
# 0      59.9
# 1      98.6
# 2      98.0
# 3      98.7
# 4      99.2
#        ...
# 947    26.9
# 948    99.0
# 949    74.7
# 950    98.1
# 951    61.0
# Name: Genome fraction (%), Length: 952, dtype: float64

# %%
df_nxt_ont_gcov_curated = pd.DataFrame({'sample_id': new_ass_ont, 'genome_cov': new_gen_cov_ont})

# %% [markdown]
# ### **Reconcile the below output and the corresponding Illumina output to remove both within and across duplicate sequencing**
# The next steps depend on these: appended `_nodup` suffix to resulting file name in `.csv` to allow filtering with `bash`

# %%
df_nxt_ont_gcov_curated[df_nxt_ont_gcov_curated['genome_cov'] >= 80.0].to_excel(glob.glob(f'{parent_dir}/**/Gisaid/ONT/ONT-genome-coverage80.xlsx')[0], index=False)

# %% [markdown]
# ### **QC final data vs. input**

# %%
df_ill_ids = pd.read_csv(glob.glob(f'{parent_dir}/**/Illumina-genome-coverage80_nodup.csv')[0], names=['sample_id'])
df_ill_ids.shape
# Out:
# (663, 1)

# %%
df_gisaid_fin.merge(df_ill_ids, how='inner', left_on='covv_provider_sample_id', right_on='sample_id').shape
# Out:
#     submitter                fn covv_virus_name        covv_type covv_passage  \
# 0      Soyola  gisaid_all.fasta         hCoV-19  betacoronavirus     Original
# 1      Soyola  gisaid_all.fasta         hCoV-19  betacoronavirus     Original
# 2      Soyola  gisaid_all.fasta         hCoV-19  betacoronavirus     Original
# 3      Soyola  gisaid_all.fasta         hCoV-19  betacoronavirus     Original
# 4      Soyola  gisaid_all.fasta         hCoV-19  betacoronavirus     Original
# ..        ...               ...             ...              ...          ...
# 645    Soyola  gisaid_all.fasta         hCoV-19  betacoronavirus     Original
# 646    Soyola  gisaid_all.fasta         hCoV-19  betacoronavirus     Original
# 647    Soyola  gisaid_all.fasta         hCoV-19  betacoronavirus     Original
# 648    Soyola  gisaid_all.fasta         hCoV-19  betacoronavirus     Original
# 649    Soyola  gisaid_all.fasta         hCoV-19  betacoronavirus     Original
#
#     covv_collection_date DT_SAM_RECEP         covv_location covv_add_location  \
# 0    2020-07-06 00:00:00          NaT  Africa/Kenya/Nairobi            Unkown
# 1    2020-07-06 00:00:00          NaT  Africa/Kenya/Nairobi            Unkown
# 2    2020-07-06 00:00:00          NaT  Africa/Kenya/Nairobi            Unkown
# 3    2020-07-06 00:00:00          NaT  Africa/Kenya/Nairobi            Unkown
# 4    2020-07-10 00:00:00          NaT  Africa/Kenya/Nairobi            Unkown
# ..                   ...          ...                   ...               ...
# 645              2021-04   2021-04-07                   NaN            Unkown
# 646              2021-04   2021-04-07                   NaN            Unkown
# 647              2021-04   2021-04-07                   NaN            Unkown
# 648              2021-04   2021-04-07                   NaN            Unkown
# 649              2021-04   2021-04-07                   NaN            Unkown
#
#     covv_host  ...                               covv_orig_lab  \
# 0       Human  ...  International Livestock Research Institute
# 1       Human  ...  International Livestock Research Institute
# 2       Human  ...  International Livestock Research Institute
# 3       Human  ...  International Livestock Research Institute
# 4       Human  ...  International Livestock Research Institute
# ..        ...  ...                                         ...
# 645     Human  ...  International Livestock Research Institute
# 646     Human  ...  International Livestock Research Institute
# 647     Human  ...  International Livestock Research Institute
# 648     Human  ...  International Livestock Research Institute
# 649     Human  ...  International Livestock Research Institute
#
#                        covv_orig_lab_addr covv_provider_sample_id  \
# 0    Uthiru, Naivasha road, Nairobi-Kenya               COVC03617
# 1    Uthiru, Naivasha road, Nairobi-Kenya               COVC03665
# 2    Uthiru, Naivasha road, Nairobi-Kenya               COVC03696
# 3    Uthiru, Naivasha road, Nairobi-Kenya               COVC03723
# 4    Uthiru, Naivasha road, Nairobi-Kenya               COVC03813
# ..                                    ...                     ...
# 645  Uthiru, Naivasha road, Nairobi-Kenya              NPHL-12773
# 646  Uthiru, Naivasha road, Nairobi-Kenya                   NPHL1
# 647  Uthiru, Naivasha road, Nairobi-Kenya                   NPHL2
# 648  Uthiru, Naivasha road, Nairobi-Kenya                   NPHL3
# 649  Uthiru, Naivasha road, Nairobi-Kenya                   NPHL4
#
#                                   covv_subm_lab  \
# 0    International Livestock Research Institute
# 1    International Livestock Research Institute
# 2    International Livestock Research Institute
# 3    International Livestock Research Institute
# 4    International Livestock Research Institute
# ..                                          ...
# 645  International Livestock Research Institute
# 646  International Livestock Research Institute
# 647  International Livestock Research Institute
# 648  International Livestock Research Institute
# 649  International Livestock Research Institute
#
#                        covv_subm_lab_addr covv_subm_sample_id  \
# 0    Uthiru, Naivasha road, Nairobi-Kenya           COVC03617
# 1    Uthiru, Naivasha road, Nairobi-Kenya           COVC03665
# 2    Uthiru, Naivasha road, Nairobi-Kenya           COVC03696
# 3    Uthiru, Naivasha road, Nairobi-Kenya           COVC03723
# 4    Uthiru, Naivasha road, Nairobi-Kenya           COVC03813
# ..                                    ...                 ...
# 645  Uthiru, Naivasha road, Nairobi-Kenya          NPHL-12773
# 646  Uthiru, Naivasha road, Nairobi-Kenya               NPHL1
# 647  Uthiru, Naivasha road, Nairobi-Kenya               NPHL2
# 648  Uthiru, Naivasha road, Nairobi-Kenya               NPHL3
# 649  Uthiru, Naivasha road, Nairobi-Kenya               NPHL4
#
#                                           covv_authors covv_comment  \
# 0    Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
# 1    Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
# 2    Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
# 3    Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
# 4    Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
# ..                                                 ...          ...
# 645  Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
# 646  Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
# 647  Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
# 648  Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
# 649  Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
#
#     comment_type   sample_id
# 0                  COVC03617
# 1                  COVC03665
# 2                  COVC03696
# 3                  COVC03723
# 4                  COVC03813
# ..           ...         ...
# 645               NPHL-12773
# 646                    NPHL1
# 647                    NPHL2
# 648                    NPHL3
# 649                    NPHL4
#
# [650 rows x 32 columns]

# %%
df_ont_ids = pd.read_csv(glob.glob(f'{parent_dir}/**/ONT-genome-coverage80.xlsx_nodup.csv')[0], names=['sample_id'])
df_ont_ids.shape
# Out:
#    sample_id
# 0  COVC14674
# 1  COVC14676
# 2  COVC14699
# 3  COVC14753
# 4  COVC14784

# %%
df_gisaid_fin.merge(df_ont_ids, how='inner', left_on='covv_provider_sample_id', right_on='sample_id').shape
# Out:
#     submitter                fn covv_virus_name        covv_type covv_passage  \
# 0      Soyola  gisaid_all.fasta         hCoV-19  betacoronavirus     Original
# 1      Soyola  gisaid_all.fasta         hCoV-19  betacoronavirus     Original
# 2      Soyola  gisaid_all.fasta         hCoV-19  betacoronavirus     Original
# 3      Soyola  gisaid_all.fasta         hCoV-19  betacoronavirus     Original
# 4      Soyola  gisaid_all.fasta         hCoV-19  betacoronavirus     Original
# ..        ...               ...             ...              ...          ...
# 645    Soyola  gisaid_all.fasta         hCoV-19  betacoronavirus     Original
# 646    Soyola  gisaid_all.fasta         hCoV-19  betacoronavirus     Original
# 647    Soyola  gisaid_all.fasta         hCoV-19  betacoronavirus     Original
# 648    Soyola  gisaid_all.fasta         hCoV-19  betacoronavirus     Original
# 649    Soyola  gisaid_all.fasta         hCoV-19  betacoronavirus     Original
#
#     covv_collection_date DT_SAM_RECEP         covv_location covv_add_location  \
# 0    2020-07-06 00:00:00          NaT  Africa/Kenya/Nairobi            Unkown
# 1    2020-07-06 00:00:00          NaT  Africa/Kenya/Nairobi            Unkown
# 2    2020-07-06 00:00:00          NaT  Africa/Kenya/Nairobi            Unkown
# 3    2020-07-06 00:00:00          NaT  Africa/Kenya/Nairobi            Unkown
# 4    2020-07-10 00:00:00          NaT  Africa/Kenya/Nairobi            Unkown
# ..                   ...          ...                   ...               ...
# 645              2021-04   2021-04-07                   NaN            Unkown
# 646              2021-04   2021-04-07                   NaN            Unkown
# 647              2021-04   2021-04-07                   NaN            Unkown
# 648              2021-04   2021-04-07                   NaN            Unkown
# 649              2021-04   2021-04-07                   NaN            Unkown
#
#     covv_host  ...                               covv_orig_lab  \
# 0       Human  ...  International Livestock Research Institute
# 1       Human  ...  International Livestock Research Institute
# 2       Human  ...  International Livestock Research Institute
# 3       Human  ...  International Livestock Research Institute
# 4       Human  ...  International Livestock Research Institute
# ..        ...  ...                                         ...
# 645     Human  ...  International Livestock Research Institute
# 646     Human  ...  International Livestock Research Institute
# 647     Human  ...  International Livestock Research Institute
# 648     Human  ...  International Livestock Research Institute
# 649     Human  ...  International Livestock Research Institute
#
#                        covv_orig_lab_addr covv_provider_sample_id  \
# 0    Uthiru, Naivasha road, Nairobi-Kenya               COVC03617
# 1    Uthiru, Naivasha road, Nairobi-Kenya               COVC03665
# 2    Uthiru, Naivasha road, Nairobi-Kenya               COVC03696
# 3    Uthiru, Naivasha road, Nairobi-Kenya               COVC03723
# 4    Uthiru, Naivasha road, Nairobi-Kenya               COVC03813
# ..                                    ...                     ...
# 645  Uthiru, Naivasha road, Nairobi-Kenya              NPHL-12773
# 646  Uthiru, Naivasha road, Nairobi-Kenya                   NPHL1
# 647  Uthiru, Naivasha road, Nairobi-Kenya                   NPHL2
# 648  Uthiru, Naivasha road, Nairobi-Kenya                   NPHL3
# 649  Uthiru, Naivasha road, Nairobi-Kenya                   NPHL4
#
#                                   covv_subm_lab  \
# 0    International Livestock Research Institute
# 1    International Livestock Research Institute
# 2    International Livestock Research Institute
# 3    International Livestock Research Institute
# 4    International Livestock Research Institute
# ..                                          ...
# 645  International Livestock Research Institute
# 646  International Livestock Research Institute
# 647  International Livestock Research Institute
# 648  International Livestock Research Institute
# 649  International Livestock Research Institute
#
#                        covv_subm_lab_addr covv_subm_sample_id  \
# 0    Uthiru, Naivasha road, Nairobi-Kenya           COVC03617
# 1    Uthiru, Naivasha road, Nairobi-Kenya           COVC03665
# 2    Uthiru, Naivasha road, Nairobi-Kenya           COVC03696
# 3    Uthiru, Naivasha road, Nairobi-Kenya           COVC03723
# 4    Uthiru, Naivasha road, Nairobi-Kenya           COVC03813
# ..                                    ...                 ...
# 645  Uthiru, Naivasha road, Nairobi-Kenya          NPHL-12773
# 646  Uthiru, Naivasha road, Nairobi-Kenya               NPHL1
# 647  Uthiru, Naivasha road, Nairobi-Kenya               NPHL2
# 648  Uthiru, Naivasha road, Nairobi-Kenya               NPHL3
# 649  Uthiru, Naivasha road, Nairobi-Kenya               NPHL4
#
#                                           covv_authors covv_comment  \
# 0    Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
# 1    Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
# 2    Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
# 3    Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
# 4    Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
# ..                                                 ...          ...
# 645  Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
# 646  Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
# 647  Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
# 648  Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
# 649  Samuel O. Oyola, Gilbert Kibet, Daniel Ouso, S...
#
#     comment_type   sample_id
# 0                  COVC03617
# 1                  COVC03665
# 2                  COVC03696
# 3                  COVC03723
# 4                  COVC03813
# ..           ...         ...
# 645               NPHL-12773
# 646                    NPHL1
# 647                    NPHL2
# 648                    NPHL3
# 649                    NPHL4
#
# [650 rows x 32 columns]

# %% [raw]
# sbatch -p batch -J sra_dwnld -n 30 --qos vip --mail-user=d.ouso@cgiar.org --mail-user=zeusfranck07yahoo.com --mail-type=BEGIN --mail-type=END -w compute05 sra.sh
